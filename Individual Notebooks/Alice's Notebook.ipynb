# %% [markdown]
# Project 4

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 1000)
from datetime import datetime as dt
import matplotlib

# %%
df = pd.read_csv('../Data/zillow_data.csv')
df
# Out:
#        RegionID  RegionName                 City State              Metro  \
# 0         84654       60657              Chicago    IL            Chicago
# 1         90668       75070             McKinney    TX  Dallas-Fort Worth
# 2         91982       77494                 Katy    TX            Houston
# 3         84616       60614              Chicago    IL            Chicago
# 4         93144       79936              El Paso    TX            El Paso
# ...         ...         ...                  ...   ...                ...
# 14718     58333        1338             Ashfield    MA    Greenfield Town
# 14719     59107        3293            Woodstock    NH          Claremont
# 14720     75672       40404                Berea    KY           Richmond
# 14721     93733       81225  Mount Crested Butte    CO                NaN
# 14722     95851       89155             Mesquite    NV          Las Vegas
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# ...

# %%
df.columns[:100]
# Out:
# Index(['RegionID', 'RegionName', 'City', 'State', 'Metro', 'CountyName',
#        'SizeRank', '1996-04', '1996-05', '1996-06', '1996-07', '1996-08',
#        '1996-09', '1996-10', '1996-11', '1996-12', '1997-01', '1997-02',
#        '1997-03', '1997-04', '1997-05', '1997-06', '1997-07', '1997-08',
#        '1997-09', '1997-10', '1997-11', '1997-12', '1998-01', '1998-02',
#        '1998-03', '1998-04', '1998-05', '1998-06', '1998-07', '1998-08',
#        '1998-09', '1998-10', '1998-11', '1998-12', '1999-01', '1999-02',
#        '1999-03', '1999-04', '1999-05', '1999-06', '1999-07', '1999-08',
#        '1999-09', '1999-10', '1999-11', '1999-12', '2000-01', '2000-02',
#        '2000-03', '2000-04', '2000-05', '2000-06', '2000-07', '2000-08',
#        '2000-09', '2000-10', '2000-11', '2000-12', '2001-01', '2001-02',
#        '2001-03', '2001-04', '2001-05', '2001-06', '2001-07', '2001-08',
#        '2001-09', '2001-10', '2001-11', '2001-12', '2002-01', '2002-02',
# ...

# %%
df.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14723 entries, 0 to 14722
# Data columns (total 272 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   RegionID    int64
#  1   RegionName  int64
#  2   City        object
#  3   State       object
#  4   Metro       object
#  5   CountyName  object
#  6   SizeRank    int64
#  7   1996-04     float64
#  8   1996-05     float64
#  9   1996-06     float64
#  10  1996-07     float64
#  11  1996-08     float64
#  12  1996-09     float64
#  13  1996-10     float64
#  14  1996-11     float64
#  15  1996-12     float64
#  16  1997-01     float64
#  17  1997-02     float64
#  18  1997-03     float64
#  19  1997-04     float64
#  20  1997-05     float64
#  21  1997-06     float64
#  22  1997-07     float64
#  23  1997-08     float64
#  24  1997-09     float64
#  25  1997-10     float64
#  26  1997-11     float64
#  27  1997-12     float64
#  28  1998-01     float64
#  29  1998-02     float64
#  30  1998-03     float64
# ...

# %%
len(df['RegionID'].unique()) # all unique values
# Out:
# 14723

# %%
len(df['RegionName'].unique()) # all unique values
# Out:
# 14723

# %%
df['City'].value_counts()[:30]
# Out:
# New York         114
# Los Angeles       95
# Houston           88
# San Antonio       48
# Washington        45
# Chicago           41
# Austin            40
# Springfield       40
# Columbus          38
# Philadelphia      38
# Las Vegas         38
# Phoenix           37
# Kansas City       37
# Dallas            35
# Portland          34
# San Diego         33
# Louisville        32
# Denver            30
# Oklahoma City     30
# Omaha             30
# Arlington         29
# Jacksonville      28
# San Jose          27
# Richmond          27
# Fort Worth        26
# Indianapolis      26
# Lincoln           25
# Charlotte         25
# Lexington         25
# Franklin          25
# Name: City, dtype: int64

# %%
df['State'].value_counts()
# Out:
# CA    1224
# NY    1015
# TX     989
# PA     831
# FL     785
# OH     588
# IL     547
# NJ     502
# MI     499
# NC     428
# IN     428
# MA     417
# TN     404
# VA     401
# MN     375
# GA     345
# WA     341
# WI     332
# MO     319
# MD     317
# CO     249
# KS     241
# AZ     230
# OR     224
# OK     221
# SC     206
# NH     199
# LA     193
# AL     183
# IA     158
# MS     153
# KY     139
# CT     124
# UT     121
# ID     110
# AR     105
# NV     103
# ME      86
# NE      83
# WV      72
# MT      71
# HI      62
# NM      60
# RI      59
# DE      41
# ND      31
# WY      31
# AK      28
# SD      19
# DC      18
# VT      16
# Name: State, dtype: int64

# %%
len(df['Metro'].value_counts())
# Out:
# 701

# %%
len(df['CountyName'].value_counts())
# Out:
# 1212

# %%
len(df['SizeRank'].value_counts()) # unique values only
# Out:
# 14723

# %%
NY_df = df.loc[df['City'] == 'New York']
NY_df
# Out:
#        RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 6         61807       10467  New York    NY  New York      Bronx         7
# 10        62037       11226  New York    NY  New York      Kings        11
# 12        62087       11375  New York    NY  New York     Queens        13
# 13        62045       11235  New York    NY  New York      Kings        14
# 20        61625       10011  New York    NY  New York   New York        21
# 21        61703       10128  New York    NY  New York   New York        22
# 35        61802       10462  New York    NY  New York      Bronx        36
# 36        61796       10456  New York    NY  New York      Bronx        37
# 46        61803       10463  New York    NY  New York      Bronx        47
# 47        62040       11230  New York    NY  New York      Kings        48
# 49        62020       11209  New York    NY  New York      Kings        50
# ...

# %%
NY_df['CountyName'].value_counts()
# Out:
# Queens      55
# Kings       28
# Bronx       13
# Richmond    12
# New York     6
# Name: CountyName, dtype: int64

# %%
# This function is provided with the starter notebook:
def melt_data(df):
    """
    Takes the zillow_data dataset in wide form or a subset of the zillow_dataset.  
    Returns a long-form datetime dataframe 
    with the datetime column names as the index and the values as the 'values' column.
    
    If more than one row is passes in the wide-form dataset, the values column
    will be the mean of the values from the datetime columns in all of the rows.
    """
    
    melted = pd.melt(df, id_vars=['RegionName', 'RegionID', 'SizeRank', 'City', 'State', 'Metro', 'CountyName'], var_name='time')
    melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
    melted = melted.dropna(subset=['value'])
    return melted.groupby('time').aggregate({'value':'mean'})

# %%
long_df = melt_data(NY_df)

# %%
long_df.shape
# Out:
# (265, 1)

# %%
long_df
# Out:
#                    value
# time
# 1996-04-01  2.148192e+05
# 1996-05-01  2.152337e+05
# 1996-06-01  2.156981e+05
# 1996-07-01  2.161865e+05
# 1996-08-01  2.167202e+05
# 1996-09-01  2.173125e+05
# 1996-10-01  2.179885e+05
# 1996-11-01  2.188394e+05
# 1996-12-01  2.199029e+05
# 1997-01-01  2.208837e+05
# 1997-02-01  2.215596e+05
# 1997-03-01  2.220519e+05
# 1997-04-01  2.225923e+05
# 1997-05-01  2.232529e+05
# 1997-06-01  2.239894e+05
# 1997-07-01  2.247788e+05
# 1997-08-01  2.256337e+05
# 1997-09-01  2.265702e+05
# 1997-10-01  2.276106e+05
# 1997-11-01  2.288519e+05
# 1997-12-01  2.302942e+05
# 1998-01-01  2.316183e+05
# 1998-02-01  2.325654e+05
# 1998-03-01  2.332942e+05
# 1998-04-01  2.340442e+05
# 1998-05-01  2.348904e+05
# 1998-06-01  2.357769e+05
# 1998-07-01  2.366808e+05
# 1998-08-01  2.376327e+05
# 1998-09-01  2.386423e+05
# 1998-10-01  2.397510e+05
# 1998-11-01  2.410635e+05
# 1998-12-01  2.425856e+05
# 1999-01-01  2.439875e+05
# 1999-02-01  2.450212e+05
# ...

# %%
new_zillow_df = pd.read_csv('../Data/Zip_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')
new_zillow_df.head(3)
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
#
#                          Metro       CountyName  2000-01-31  ...  2021-06-30  \
# 0  New York-Newark-Jersey City  New York County    322791.0  ...   1098893.0
# 1     Chicago-Naperville-Elgin      Cook County    312893.0  ...    512225.0
# 2  New York-Newark-Jersey City  New York County    503959.0  ...   1458014.0
#
#    2021-07-31  2021-08-31  2021-09-30  2021-10-31  2021-11-30  2021-12-31  \
# 0   1107554.0   1116367.0   1126666.0   1131034.0   1130418.0   1130985.0
# 1    516042.0    520532.0    523117.0    525702.0    528495.0    530491.0
# 2   1459861.0   1474220.0   1489954.0   1498567.0   1502806.0   1503119.0
#
#    2022-01-31  2022-02-28  2022-03-31
# ...

# %%
new_zillow_df['City'].value_counts()
# Out:
# New York           178
# Houston            106
# Los Angeles        100
# Chicago             56
# San Antonio         55
#                   ...
# Blissfield           1
# Igo                  1
# Seibert              1
# Daykin               1
# Washingtonville      1
# Name: City, Length: 13886, dtype: int64
