# %% [markdown]
# Project 4

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 1000)
from datetime import datetime as dt
import matplotlib

# %%
df = pd.read_csv('../Data/zillow_data.csv')
df
# Out:
#        RegionID  RegionName                 City State              Metro  \
# 0         84654       60657              Chicago    IL            Chicago
# 1         90668       75070             McKinney    TX  Dallas-Fort Worth
# 2         91982       77494                 Katy    TX            Houston
# 3         84616       60614              Chicago    IL            Chicago
# 4         93144       79936              El Paso    TX            El Paso
# ...         ...         ...                  ...   ...                ...
# 14718     58333        1338             Ashfield    MA    Greenfield Town
# 14719     59107        3293            Woodstock    NH          Claremont
# 14720     75672       40404                Berea    KY           Richmond
# 14721     93733       81225  Mount Crested Butte    CO                NaN
# 14722     95851       89155             Mesquite    NV          Las Vegas
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# ...

# %%
df.columns[:100]
# Out:
# Index(['RegionID', 'RegionName', 'City', 'State', 'Metro', 'CountyName',
#        'SizeRank', '1996-04', '1996-05', '1996-06', '1996-07', '1996-08',
#        '1996-09', '1996-10', '1996-11', '1996-12', '1997-01', '1997-02',
#        '1997-03', '1997-04', '1997-05', '1997-06', '1997-07', '1997-08',
#        '1997-09', '1997-10', '1997-11', '1997-12', '1998-01', '1998-02',
#        '1998-03', '1998-04', '1998-05', '1998-06', '1998-07', '1998-08',
#        '1998-09', '1998-10', '1998-11', '1998-12', '1999-01', '1999-02',
#        '1999-03', '1999-04', '1999-05', '1999-06', '1999-07', '1999-08',
#        '1999-09', '1999-10', '1999-11', '1999-12', '2000-01', '2000-02',
#        '2000-03', '2000-04', '2000-05', '2000-06', '2000-07', '2000-08',
#        '2000-09', '2000-10', '2000-11', '2000-12', '2001-01', '2001-02',
#        '2001-03', '2001-04', '2001-05', '2001-06', '2001-07', '2001-08',
#        '2001-09', '2001-10', '2001-11', '2001-12', '2002-01', '2002-02',
# ...

# %%
df.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14723 entries, 0 to 14722
# Data columns (total 272 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   RegionID    int64
#  1   RegionName  int64
#  2   City        object
#  3   State       object
#  4   Metro       object
#  5   CountyName  object
#  6   SizeRank    int64
#  7   1996-04     float64
#  8   1996-05     float64
#  9   1996-06     float64
#  10  1996-07     float64
#  11  1996-08     float64
#  12  1996-09     float64
#  13  1996-10     float64
#  14  1996-11     float64
#  15  1996-12     float64
#  16  1997-01     float64
#  17  1997-02     float64
#  18  1997-03     float64
#  19  1997-04     float64
#  20  1997-05     float64
#  21  1997-06     float64
#  22  1997-07     float64
#  23  1997-08     float64
#  24  1997-09     float64
#  25  1997-10     float64
#  26  1997-11     float64
#  27  1997-12     float64
#  28  1998-01     float64
#  29  1998-02     float64
#  30  1998-03     float64
# ...

# %%
df['City'].value_counts()
# Out:
# New York         114
# Los Angeles       95
# Houston           88
# San Antonio       48
# Washington        45
#                 ...
# Scipio             1
# Crete              1
# Mohnton            1
# Spanish Fork       1
# Mount Rainier      1
# Name: City, Length: 7554, dtype: int64

# %%
df['State'].value_counts()
# Out:
# CA    1224
# NY    1015
# TX     989
# PA     831
# FL     785
# OH     588
# IL     547
# NJ     502
# MI     499
# NC     428
# IN     428
# MA     417
# TN     404
# VA     401
# MN     375
# GA     345
# WA     341
# WI     332
# MO     319
# MD     317
# CO     249
# KS     241
# AZ     230
# OR     224
# OK     221
# SC     206
# NH     199
# LA     193
# AL     183
# IA     158
# MS     153
# KY     139
# CT     124
# UT     121
# ID     110
# AR     105
# NV     103
# ME      86
# NE      83
# WV      72
# MT      71
# HI      62
# NM      60
# RI      59
# DE      41
# WY      31
# ND      31
# AK      28
# SD      19
# DC      18
# VT      16
# Name: State, dtype: int64

# %%
df = df.loc[df['State'] == 'WA']

# %%
df
# Out:
#        RegionID  RegionName                       City State         Metro  \
# 67        99534       98052                    Redmond    WA       Seattle
# 143       99500       98012                    Bothell    WA       Seattle
# 161       99563       98103                    Seattle    WA       Seattle
# 180      100179       99301                      Pasco    WA     Kennewick
# 331       99575       98115                    Seattle    WA       Seattle
# 380       99961       98682                  Vancouver    WA      Portland
# 384       99589       98133                  Shoreline    WA       Seattle
# 404      100157       99208                    Spokane    WA       Spokane
# 438       99581       98122                    Seattle    WA       Seattle
# 446       99930       98632                   Longview    WA      Longview
# 517       99631       98208   Seattle Hill-Silver Firs    WA       Seattle
# ...

# %%
df = df.loc[df['City'] == 'Tacoma']

# %%
df
# Out:
#       RegionID  RegionName    City State    Metro CountyName  SizeRank  \
# 3653     99786       98404  Tacoma    WA  Seattle     Pierce      3654
# 3967     99787       98405  Tacoma    WA  Seattle     Pierce      3968
# 4187     99791       98409  Tacoma    WA  Seattle     Pierce      4188
# 4618     99788       98406  Tacoma    WA  Seattle     Pierce      4619
# 4777     99789       98407  Tacoma    WA  Seattle     Pierce      4778
# 5828     99799       98422  Tacoma    WA  Seattle     Pierce      5829
# 6013     99790       98408  Tacoma    WA  Seattle     Pierce      6014
# 8296     99785       98403  Tacoma    WA  Seattle     Pierce      8297
# 8622     99797       98418  Tacoma    WA  Seattle     Pierce      8623
# 8667     99784       98402  Tacoma    WA  Seattle     Pierce      8668
# 9166     99816       98465  Tacoma    WA  Seattle     Pierce      9167
#
#        1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  2017-10  \
# ...
